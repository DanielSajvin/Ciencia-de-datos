# %%
from transformers import pipeline

# %%
clasificador = pipeline(
    "sentiment-analysis",
    model="dccuchile/bert-base-spanish-wwm-cased",
    tokenizer="dccuchile/bert-base-spanish-wwm-cased",
)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dccuchile/bert-base-spanish-wwm-cased and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Device set to use cpu
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:  41%|####      | 178M/440M [00:00<?, ?B/s]
# Error while downloading from https://huggingface.co/dccuchile/bert-base-spanish-wwm-cased/resolve/refs%2Fpr%2F3/model.safetensors: HTTPSConnectionPool(host='cas-bridge.xethub.hf.co', port=443): Read timed out.
# Trying to resume download...
# model.safetensors:  86%|########5 | 377M/440M [00:00<?, ?B/s]
# ...

# %%
textos = [
    "Me encanta este producto, superó todas mis expectativas",
    "El servico al cliente fue pésimo y el envio tardó demasiado",
    "La calidad es decente, pero no es nada del otro mundo",
    "Era justo lo que buscaba",
    "Todos deberíamos tener uno"
]

# %%
# realizar la predicción
prediccion = clasificador(textos)

# %%
for texto, resultado in zip(textos, prediccion):
    # \nPredicción: {resultado}\n")
    sentimiento = resultado["label"]
    puntuacion = resultado["score"]
    print("-" * 30)
    print(f"Texto: ***{texto}***")
    print(f"Sentimiento: ***{sentimiento}***")
    print(f"Confianza: ***{puntuacion:.4f}***")
# Out:
# Texto: Me encanta este producto, superó todas mis expectativas
# Sentimiento: NEGATIVE, Puntuación: 0.9542
#
# Texto: El servico al cliente fue pésimo y el envio tardó demasiado
# Sentimiento: NEGATIVE, Puntuación: 0.6589
#
# Texto: La calidad es decente, pero no es nada del otro mundo
# Sentimiento: NEGATIVE, Puntuación: 0.9765
#
# Texto: Era justo lo que buscaba
# Sentimiento: POSITIVE, Puntuación: 0.9166
#
# Texto: Todos deberíamos tener uno
# Sentimiento: NEGATIVE, Puntuación: 0.8730
